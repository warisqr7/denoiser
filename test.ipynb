# %%
from IPython import display as disp
import torch
import torchaudio
from denoiser import pretrained
from denoiser.dsp import convert_audio

from denoiser.demucs import Demucs

# %%
# Downloading a test file
# !wget https://facebookresearch.github.io/denoiser/audio/noisy/alex_noisy.mp3

# %%
url = "/mnt/nvme-data1/waris/Sairen/repo/denoiser/outputs/exp_batch_size=32,demucs.causal=1,demucs.hidden=32,demucs.resample=4,dset=dns,epochs=250,revecho=1,segment=10,shift=16000,shift_same=True,stride=2/best.th"

# %%
model = Demucs(hidden=32)
state_dict = torch.load(url, map_location='cpu')
model.load_state_dict(state_dict['state'])

model = model.cuda()

# %%
wav, sr = torchaudio.load('alex_noisy.mp3')
wav = convert_audio(wav.cuda(), sr, model.sample_rate, model.chin)
with torch.no_grad():
    denoised = model(wav[None])[0]
disp.display(disp.Audio(wav.data.cpu().numpy(), rate=model.sample_rate))
disp.display(disp.Audio(denoised.data.cpu().numpy(), rate=model.sample_rate))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
